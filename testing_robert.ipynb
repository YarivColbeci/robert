# %%
from extension_board import ExtensionBoard
import time
import cv2
import nanocamera as nano

from IPython.display import display, Image
import IPython.display

board = ExtensionBoard()

# %%
board.buzz(0)

# %%
gst_pipeline = (
    "nvarguscamerasrc ! "
    "video/x-raw(memory:NVMM), width=1280, height=720, framerate=30/1 ! "
    "nvvidconv ! video/x-raw, format=BGRx ! videoconvert ! appsink"
)

cap = cv2.VideoCapture(gst_pipeline, cv2.CAP_GSTREAMER)

if not cap.isOpened():
    print("Cannot open CSI camera")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break
    # Convert to JPEG and display in notebook
    ret, jpeg = cv2.imencode('.jpg', frame)
    IPython.display.display(IPython.display.Image(data=jpeg.tobytes()))
    IPython.display.clear_output(wait=True)
    #time.sleep(0.05)  # small delay
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ed311242f4ed> in <module>
#      16         break
#      17     # Convert to JPEG and display in notebook
# ---> 18     ret, jpeg = cv2.imencode('.jpg', frame)
#      19     IPython.display.display(IPython.display.Image(data=jpeg.tobytes()))
#      20     IPython.display.clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
cap.release()
